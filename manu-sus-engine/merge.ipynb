# %%
import os
import pandas as pd

file_path = "process_dataset.xlsx"

output_folder = "batch_csv_files"
os.makedirs(output_folder, exist_ok=True)

xls = pd.ExcelFile(file_path)

for sheet_name in xls.sheet_names:
    
    df = pd.read_excel(file_path, sheet_name=sheet_name)
    
    df.to_csv(f"{output_folder}/{sheet_name}.csv", index=False)

print("CSV files saved in folder.")

# %%
excel_path1 = r'/Users/suhaas/Machine-Learning/manu-sus-engine/_h_batch_process_data.xlsx'
csv_path1 = r'/Users/suhaas/Machine-Learning/manu-sus-engine/_h_batch_process_data.csv'
excel_path2 = r'/Users/suhaas/Machine-Learning/manu-sus-engine/_h_batch_production_data.xlsx'
csv_path2 = r'/Users/suhaas/Machine-Learning/manu-sus-engine/_h_batch_production_data.csv'

df1 = pd.read_excel(excel_path1)
df1.to_csv(csv_path1, index=False)

df2 = pd.read_excel(excel_path2)
df2.to_csv(csv_path2, index=False)

print(f"✓ Successfully converted Excel file to CSV")
print(f"Output file: {csv_path1}")
print(f"Shape: {df1.shape}")
print(f"Output file: {csv_path2}")
print(f"Shape: {df2.shape}")
