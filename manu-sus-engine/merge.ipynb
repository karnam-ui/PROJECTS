# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=df.drop(columns=["Phases"])

# %%
df.head()
# Out:
#   Batch_ID  Duration_Minutes  Data_Points  Avg_Temperature  Max_Temperature  \
# 0     T001               210          211        35.222405        64.464826
# 1     T002               242          243        34.118974        68.199612
# 2     T003               257          258        35.232192        65.789715
# 3     T004               231          232        37.009830        68.036694
# 4     T005               246          247        33.918228        74.712142
#
#    Avg_Pressure  Max_Compression_Force  Avg_Power_Consumption  Max_Motor_Speed
# 0      0.989573              14.219469              21.821216       875.033250
# 1      0.990320              18.252780              21.761982       870.711447
# 2      0.973079              12.139067              23.328404       876.255527
# 3      0.969539              10.457428              21.305877       854.039596
# 4      0.969525              18.036629              24.982074       906.424204
